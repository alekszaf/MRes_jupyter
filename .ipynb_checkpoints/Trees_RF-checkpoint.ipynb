# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
pd.set_option('display.max_columns', None)

# %%
trees = pd.read_csv('C:\\Temp\\MRes\\training_data\\AB_3cat.csv')

# %%
# def prepare_xy(file):
#     trees = pd.read_csv(file)
#     trees = trees.drop(columns=['geometry'])
#     trees = trees.to_numpy()
#     X, y = trees[:,1:], trees[:,0]
#     X = X.astype('float32')
#     y = y.astype('str')
#     y = LabelEncoder().fit_transform(y)
#     return(X, y)

# %%
trees.head()
# Out:
#    GENUS  All.returns.above.2  All.returns.above.mean  All.returns.above.mode  \
# 0  Tilia                 1920                     827                     942
# 1   Acer                 1015                     572                     798
# 2   Acer                  366                     202                     189
# 3   Acer                  177                     126                      96
# 4   Acer                 1028                     476                     735
#
#    Canopy.relief.ratio  First.returns.above.2  First.returns.above.mean  \
# 0             0.329585                   1416                       723
# 1             0.556663                    708                       527
# 2             0.440053                    337                       199
# 3             0.802231                    142                       124
# 4             0.470105                    833                       440
#
#    First.returns.above.mode  H01TH  H05TH  H10TH  H15TH  H20TH  H25TH  H30TH  \
# 0                       811   5.04   5.18   5.33   5.45   5.62   5.75   5.88
# 1                       244   5.06   5.34   5.65   6.16   6.70   7.15   7.57
# 2                       187   5.05   5.18   5.26   5.35   5.49   5.62   5.69
# 3                        79   6.05   7.56  10.16  11.30  11.95  12.09  12.29
# 4                       615   5.09   5.23   5.45   5.63   5.86   6.06   6.20
#
#    H35TH  H40TH  H45TH  H50TH  H55TH  H60TH  H65TH  H70TH  H75TH  H80TH  \
# 0   6.01   6.13   6.24   6.33   6.43   6.55   6.70   6.91   7.14   7.63
# 1   7.95   8.42   9.15   9.59  10.04  10.25  10.43  10.69  10.90  11.36
# 2   5.79   5.97   6.15   6.21   6.28   6.33   6.40   6.48   6.56   6.76
# 3  12.52  12.62  12.71  12.84  12.89  12.94  12.98  13.05  13.12  13.21
# 4   6.33   6.45   6.60   6.73   6.93   7.22   7.44   7.66   7.81   8.05
#
#    H90TH  H95TH  H99TH    HCV  HKUR   HMAX  HMEADIAN  HMEAN  HMODE   HSD  \
# 0   7.91   8.10   8.71  14.31  2.47   9.49      6.33   6.48   6.34  0.93
# 1  11.48  11.63  11.96  23.84  1.77  12.20      9.59   9.01  10.90  2.15
# 2   6.91   7.02   7.31   9.77  1.98   7.53      6.21   6.11   6.19  0.60
# 3  13.31  13.38  13.71  13.65  7.95  13.74     12.84  12.20  12.89  1.67
# 4   8.24   8.46   8.79  15.01  1.85   8.96      6.73   6.86   6.16  1.03
#
#    HSKE  HVAR   I01TH   I05TH   I10TH    I15TH   I20TH   I25TH   I30TH  \
# 0  0.51  0.86  488.38   689.8   920.6  1076.70  1279.0  1446.0  1622.4
# 1 -0.39  4.61  453.00   517.0   620.6   808.20  1050.8  1462.5  2222.2
# 2 -0.05  0.36  615.30  1255.0  1680.0  2468.00  3191.0  3687.0  4109.0
# 3 -2.34  2.77  483.76   658.4  1315.0  1622.60  2280.2  3000.0  3809.2
# 4  0.04  1.06  539.00   785.4  1127.4  1510.35  2142.4  2799.0  3320.9
#
#      I35TH   I40TH   I45TH   I50TH   I55TH   I60TH    ICV  IKUR   IMAX  \
# 0  1828.00  2019.0  2187.0  2396.0  2594.9  2845.8  57.01  2.96   8143
# 1  3103.00  3745.0  4342.3  4888.0  5400.2  5907.4  62.31  1.67  10579
# 2  4408.25  4700.0  4954.5  5196.0  5527.0  5852.0  45.95  2.23  10346
# 3  4389.60  4794.2  5206.2  5568.0  5878.2  6266.0  48.64  2.00   9915
# 4  3683.85  4060.2  4513.3  4733.0  4975.0  5271.6  48.81  2.12  10206
#
#    IMEADIAN    IMEAN  IMODE     IP65    IP70     IP75    IP80    IP90  \
# 0    2396.0  2670.93    879  3064.40  3321.5  3622.75  4373.3  4933.4
# 1    4888.0  4533.38    444  6305.30  6624.6  6900.50  7711.5  8054.4
# 2    5196.0  5328.16   4331  6300.25  6722.0  7164.50  8163.5  8880.0
# 3    5568.0  5062.11   1228  6551.00  6797.0  7054.00  7679.2  7880.8
# 4    4733.0  4454.68   4733  5569.85  5862.6  6121.50  6782.1  7135.3
#
#       IP95      IP99      ISD  ISKE        IVAR  \
# 0  5497.20   6831.53  1522.59  0.73  2318274.94
# 1  8659.20   9642.54  2824.58 -0.06  7978231.46
# 2  9305.50  10190.25  2448.45  0.00  5994906.73
# 3  8214.60   9003.28  2462.13 -0.41  6062069.68
# 4  7631.45   8745.74  2174.35 -0.18  4727797.24
#
#    Percentage.all.returns.above.mean  Percentage.all.returns.above.mode  \
# 0                          43.072917                          49.062500
# 1                          56.354680                          78.620690
# 2                          55.191257                          51.639344
# 3                          71.186441                          54.237288
# 4                          46.303502                          71.498054
#
#    Percentage.first.returns.above.mean  Percentage.first.returns.above.mode  \
# 0                            51.059322                            57.274011
# 1                            74.435028                            34.463277
# 2                            59.050445                            55.489614
# 3                            87.323944                            55.633803
# 4                            52.821128                            73.829532
#
#    Return.1.count.above.2  Return.2.count.above.2  Return.3.count.2  \
# 0                    1416                     433                66
# 1                     708                     206                77
# 2                     337                      29                 0
# 3                     142                      32                 2
# 4                     833                     184                11
#
#    Return.4.count.2  Return.5.count.2  Return.6.count.2  \
# 0                 5                 0                 0
# 1                22                 1                 1
# 2                 0                 0                 0
# 3                 1                 0                 0
# 4                 0                 0                 0
#
#    Return.7.count.above.2  Total.all.return.count  \
# 0                       0                    1920
# 1                       0                    1015
# 2                       0                     366
# 3                       0                     177
# 4                       0                    1028
#
#    Total.all.return.count.above.2  Total.first.return.count  b_max     b_mean  \
# 0                            1920                      1416    142  64.965399
# 1                            1015                       708    127  60.392079
# 2                             366                       337    124  64.554241
# 3                             177                       142    135  64.611111
# 4                            1028                       833    131  57.770553
#
#    b_median  b_min  crownArea  g_max     g_mean  g_median  g_min  \
# 0      64.0      1      67.05    181  94.354064      89.0     36
# 1      58.0      1      45.45    153  83.174697      82.0     37
# 2      62.0     18      15.21    146  81.047995      81.0     32
# 3      63.0     24       4.68    156  84.782051      83.0     44
# 4      55.0     18      69.21    137  63.370611      61.0     32
#
#                                             geometry  r_max      r_mean  \
# 0  POLYGON ((423712.8 564644.1, 423712.8 564643.8...    200  104.325578
# 1  POLYGON ((423819.9 564730.2, 423819.9 564729.9...    153   76.669527
# 2  POLYGON ((423469.5 564817.8, 423469.5 564817.5...    139   77.166995
# 3  POLYGON ((423754.2 564619.8, 423754.2 564619.5...    148   76.688034
# 4  POLYGON ((423400.2 564846.9, 423400.2 564846.6...    135   57.520590
#
#    r_median  r_min
# 0      93.0     33
# 1      76.0     28
# 2      74.0     29
# 3      75.0     34
# 4      56.0     22

# %%
trees = trees.drop(columns=['geometry'])

# %%
#trees = trees.to_numpy()

# %%
X, y = trees.iloc[:,1:], trees.iloc[:,0].values

# %%
X = X.astype('float32')
y = y.astype('str')

# %%
# y = LabelEncoder().fit_transform(y)

# %%
# Evaluate naive

# Instantiate a DummyClassifier with 'most_frequent' strategy
naive = DummyClassifier(strategy='most_frequent')

# Create RepeatedStratifiedKFold cross-validator with 10 folds, 3 repeats and a seed of 1.
cv = RepeatedStratifiedKFold(n_splits = 10, n_repeats = 3, random_state=1)

# Calculate accuracy using `cross_val_score()` with model instantiated, data to fit, target variable, 'accuracy' scoring, cross validator, n_jobs=-1, and error_score set to 'raise'
n_scores = cross_val_score(naive, X, y, scoring='accuracy', cv=cv, n_jobs=1, error_score='raise')

# Print mean and standard deviation of n_scores: 
print('Naive score: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Naive score: 0.333 (0.000)

# %%
# Evaluate baseline model

# Instantiate a DecisionTreeClassifier
model = DecisionTreeClassifier()

# Calculate accuracy using `cross_val_score()` with model instantiated, data to fit, target variable, 'accuracy' scoring, cross validator 'cv', and error_score set to 'raise'
m_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, error_score='raise')

# Print mean and standard deviation of m_scores: 
print('Baseline score: %.3f (%.3f)' % (mean(m_scores), std(m_scores)))
# Out:
# Baseline score: 0.630 (0.064)

# %%
# Import several other classifiers for ensemble
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
cv = RepeatedStratifiedKFold(n_splits= 10, n_repeats=5, random_state= 1)

clf = RandomForestClassifier()
clf2 = SVC(gamma = 0.1)
clf3 = AdaBoostClassifier()

clf_scores = cross_val_score(clf, X, y, scoring='accuracy', error_score='raise', cv = cv)
clf_scores2 = cross_val_score(clf2, X, y, scoring='accuracy', error_score='raise', cv = cv)
clf_scores3 = cross_val_score(clf3, X, y, scoring='accuracy', error_score='raise', cv = cv)

print('Baseline score: %.3f (%.3f)' % (mean(clf_scores), std(clf_scores)))
print('Baseline score: %.3f (%.3f)' % (mean(clf_scores2), std(clf_scores2)))
print('Baseline score: %.3f (%.3f)' % (mean(clf_scores3), std(clf_scores3)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Baseline score: 0.730 (0.056)
# Baseline score: 0.502 (0.004)
# Baseline score: 0.677 (0.064)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat_rf = confusion_matrix(y, y_pred)

y_pred = cross_val_predict(clf2, X, y, cv=10)
conf_mat_svm = confusion_matrix(y, y_pred)

y_pred = cross_val_predict(clf3, X, y, cv=10)
conf_mat_ada = confusion_matrix(y, y_pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    
    plt.savefig('C:\\Temp\\MRes\\Figures\\cm_svm_ab_3cat.eps')
    
    plt.show()

# %%
plot_confusion_matrix(conf_mat_rf, normalize = False, target_names = ['Acer', 'Prunus', 'Tilia'])
plt.savefig('C:\\Temp\\MRes\\Figures\\cm_rf_ab_3cat.eps')

# %%
plot_confusion_matrix(conf_mat_svm, normalize = False, target_names = ['Acer', 'Prunus', 'Tilia'])
#plt.savefig('C:\\Temp\\MRes\\Figures\\cm_svm_ab_3cat.eps')
# Out:
# <img src="data:image/png;base64,..." width="976.7272727272727">

# %%
# %matplotlib notebook
plot_confusion_matrix(conf_mat_ada, normalize = False, target_names = ['Acer', 'Prunus', 'Tilia'])
#plt.savefig('C:\\Temp\\MRes\\Figures\\cm_ada_ab_3cat.png')
# Out:
# <img src="data:image/png;base64,..." width="957.8181818181819">

# %%
from sklearn.model_selection import cross_validate

clf=RandomForestClassifier(n_estimators =10, random_state = 42, class_weight="balanced")
output = cross_validate(clf, X, y, cv=cv, scoring = 'accuracy', return_estimator =True)

# %%
for idx,estimator in enumerate(output['estimator']):
    print("Features sorted by their score for estimator {}:".format(idx))
    feature_importances = pd.DataFrame(estimator.feature_importances_,
                                       index = X.columns,
                                        columns=['importance']).sort_values('importance', ascending=False)
    print(feature_importances)
# Out:
# Features sorted by their score for estimator 0:
#                           importance
# ISD                         0.079368
# IVAR                        0.057862
# IP95                        0.052890
# I55TH                       0.029212
# ISKE                        0.028621
# ...                              ...
# First.returns.above.mean    0.000733
# Return.6.count.2            0.000723
# I20TH                       0.000542
# Return.5.count.2            0.000125
# Return.7.count.above.2      0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 1:
#                         importance
# ISD                       0.094510
# IP95                      0.059378
# IVAR                      0.052717
# ISKE                      0.051841
# I55TH                     0.033876
# ...                            ...
# Return.1.count.above.2    0.000989
# IP75                      0.000723
# Return.6.count.2          0.000000
# HMEAN                     0.000000
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 2:
#                           importance
# ISD                         0.083696
# IVAR                        0.065894
# IP95                        0.056297
# ISKE                        0.053089
# I45TH                       0.032209
# ...                              ...
# Return.5.count.2            0.000568
# First.returns.above.mean    0.000380
# Return.6.count.2            0.000281
# Return.7.count.above.2      0.000000
# Return.2.count.above.2      0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 3:
#                         importance
# ISD                       0.089697
# IVAR                      0.067304
# IP95                      0.042991
# ISKE                      0.033188
# I55TH                     0.029885
# ...                            ...
# H05TH                     0.001969
# Return.6.count.2          0.001608
# Return.5.count.2          0.001530
# H25TH                     0.001254
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 4:
#                         importance
# ISD                       0.102029
# IP95                      0.077168
# ISKE                      0.061094
# IVAR                      0.042170
# I55TH                     0.038478
# ...                            ...
# H55TH                     0.000758
# Return.5.count.2          0.000262
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
# H90TH                     0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 5:
#                         importance
# ISD                       0.100491
# IP95                      0.068656
# ISKE                      0.058715
# IVAR                      0.040923
# I55TH                     0.023714
# ...                            ...
# Return.4.count.2          0.001454
# Return.3.count.2          0.000476
# HMEAN                     0.000406
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 6:
#                         importance
# ISD                       0.091941
# IP95                      0.067621
# IVAR                      0.058376
# ISKE                      0.052580
# I55TH                     0.028082
# ...                            ...
# Return.1.count.above.2    0.001510
# IP70                      0.001492
# H55TH                     0.001212
# Return.6.count.2          0.001133
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 7:
#                                 importance
# ISD                               0.103252
# ISKE                              0.059323
# IVAR                              0.051440
# IP95                              0.048329
# I55TH                             0.028266
# ...                                    ...
# H01TH                             0.001163
# Total.all.return.count.above.2    0.001014
# Return.1.count.above.2            0.000428
# Return.7.count.above.2            0.000000
# Return.6.count.2                  0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 8:
#                         importance
# ISD                       0.077726
# IVAR                      0.066028
# ISKE                      0.046581
# IP95                      0.041899
# I55TH                     0.026482
# ...                            ...
# I20TH                     0.002399
# I15TH                     0.001864
# HVAR                      0.001693
# Return.6.count.2          0.001063
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 9:
#                         importance
# ISD                       0.102240
# IP95                      0.059389
# IVAR                      0.053972
# ISKE                      0.034098
# I55TH                     0.022274
# ...                            ...
# Return.6.count.2          0.001757
# H50TH                     0.001562
# H70TH                     0.001478
# H20TH                     0.001381
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 10:
#                                      importance
# ISD                                    0.092461
# IVAR                                   0.060467
# IP95                                   0.042680
# ISKE                                   0.040973
# I55TH                                  0.029798
# ...                                         ...
# Percentage.first.returns.above.mode    0.001924
# Return.7.count.above.2                 0.000000
# Return.6.count.2                       0.000000
# Return.5.count.2                       0.000000
# HMEAN                                  0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 11:
#                         importance
# ISD                       0.110469
# IP95                      0.057271
# IVAR                      0.050235
# ISKE                      0.033775
# I55TH                     0.025591
# ...                            ...
# I10TH                     0.001566
# b_median                  0.001454
# H05TH                     0.000414
# Return.6.count.2          0.000089
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 12:
#                         importance
# ISD                       0.088626
# ISKE                      0.057362
# IP95                      0.051217
# IVAR                      0.047887
# I55TH                     0.032826
# ...                            ...
# Return.1.count.above.2    0.000614
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
# H55TH                     0.000000
# H50TH                     0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 13:
#                         importance
# ISD                       0.083982
# ISKE                      0.083047
# IP95                      0.059223
# IVAR                      0.044344
# IP80                      0.027473
# ...                            ...
# Return.4.count.2          0.001664
# H70TH                     0.001577
# HMEAN                     0.001488
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 14:
#                         importance
# ISD                       0.080991
# IP95                      0.058885
# IVAR                      0.044656
# ISKE                      0.043924
# IP90                      0.026156
# ...                            ...
# H90TH                     0.001948
# Return.6.count.2          0.001797
# Return.5.count.2          0.000360
# r_min                     0.000199
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 15:
#                         importance
# ISD                       0.088960
# IP95                      0.070066
# IVAR                      0.053460
# ISKE                      0.042101
# I55TH                     0.030331
# ...                            ...
# H50TH                     0.001988
# g_mean                    0.000791
# Return.6.count.2          0.000586
# H70TH                     0.000411
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 16:
#                         importance
# ISD                       0.110982
# ISKE                      0.067027
# IP95                      0.048076
# I55TH                     0.036014
# IVAR                      0.033007
# ...                            ...
# g_median                  0.001258
# Return.6.count.2          0.000000
# I20TH                     0.000000
# Return.7.count.above.2    0.000000
# Return.5.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 17:
#                         importance
# ISD                       0.079463
# ISKE                      0.070242
# IP95                      0.053374
# ICV                       0.037148
# IVAR                      0.034242
# ...                            ...
# H20TH                     0.002020
# Return.6.count.2          0.000629
# All.returns.above.mode    0.000385
# Return.7.count.above.2    0.000000
# Return.5.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 18:
#                         importance
# ISD                       0.089950
# IP95                      0.052425
# ISKE                      0.038693
# IVAR                      0.037533
# I45TH                     0.030092
# ...                            ...
# H55TH                     0.001081
# H15TH                     0.000360
# Return.5.count.2          0.000043
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 19:
#                                    importance
# ISD                                  0.086618
# IP95                                 0.066104
# IVAR                                 0.052333
# ISKE                                 0.052200
# I45TH                                0.028530
# ...                                       ...
# Return.3.count.2                     0.000848
# I20TH                                0.000683
# Percentage.all.returns.above.mean    0.000305
# Return.7.count.above.2               0.000000
# Return.6.count.2                     0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 20:
#                         importance
# ISD                       0.093252
# ISKE                      0.073093
# IVAR                      0.060820
# I55TH                     0.038090
# IP95                      0.031579
# ...                            ...
# g_mean                    0.002072
# IP70                      0.001816
# HMEADIAN                  0.000917
# Return.6.count.2          0.000000
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 21:
#                         importance
# ISD                       0.096058
# IVAR                      0.054596
# IP95                      0.054169
# ISKE                      0.037091
# IKUR                      0.035149
# ...                            ...
# H40TH                     0.001906
# H05TH                     0.001453
# H10TH                     0.000879
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 22:
#                                 importance
# ISD                               0.072004
# IVAR                              0.061814
# IP95                              0.047769
# ISKE                              0.044666
# I55TH                             0.036595
# ...                                    ...
# Total.all.return.count.above.2    0.001553
# First.returns.above.mode          0.001143
# H20TH                             0.001110
# Return.6.count.2                  0.000701
# Return.7.count.above.2            0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 23:
#                         importance
# ISD                       0.090631
# IP95                      0.063091
# ISKE                      0.057749
# IVAR                      0.044548
# I55TH                     0.028992
# ...                            ...
# Return.5.count.2          0.001847
# H90TH                     0.001779
# HMEADIAN                  0.001654
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 24:
#                         importance
# ISD                       0.098263
# ISKE                      0.069010
# IP95                      0.050987
# IVAR                      0.041471
# IP99                      0.024603
# ...                            ...
# H50TH                     0.002233
# H01TH                     0.001926
# Return.5.count.2          0.000608
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 25:
#                                    importance
# ISD                                  0.081622
# ISKE                                 0.059384
# IP95                                 0.049825
# IVAR                                 0.039477
# I55TH                                0.027733
# ...                                       ...
# H30TH                                0.000441
# Return.6.count.2                     0.000381
# Percentage.all.returns.above.mode    0.000304
# Return.7.count.above.2               0.000000
# Return.5.count.2                     0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 26:
#                           importance
# ISD                         0.082478
# IVAR                        0.061741
# ISKE                        0.054089
# IP95                        0.046688
# I55TH                       0.034292
# ...                              ...
# First.returns.above.mean    0.001600
# I50TH                       0.001017
# Return.6.count.2            0.000307
# Return.7.count.above.2      0.000000
# H45TH                       0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 27:
#                         importance
# ISD                       0.104076
# IP95                      0.066454
# ISKE                      0.059906
# IVAR                      0.050499
# I55TH                     0.046246
# ...                            ...
# H70TH                     0.001575
# H40TH                     0.001281
# H50TH                     0.001126
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 28:
#                         importance
# ISD                       0.102070
# IVAR                      0.054041
# IP95                      0.054035
# ISKE                      0.045025
# ICV                       0.024252
# ...                            ...
# H25TH                     0.002106
# H70TH                     0.002019
# Return.6.count.2          0.000738
# HMEADIAN                  0.000634
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 29:
#                         importance
# ISD                       0.102554
# ISKE                      0.064499
# IP95                      0.057128
# I55TH                     0.033686
# IVAR                      0.031914
# ...                            ...
# I50TH                     0.002048
# Return.5.count.2          0.001409
# H50TH                     0.001329
# Return.6.count.2          0.000358
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 30:
#                         importance
# ISD                       0.108566
# IVAR                      0.042683
# ISKE                      0.039004
# I60TH                     0.029566
# I55TH                     0.028770
# ...                            ...
# HCV                       0.001790
# Return.2.count.above.2    0.001784
# Return.5.count.2          0.001643
# Return.6.count.2          0.001197
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 31:
#                         importance
# ISD                       0.086127
# ISKE                      0.061569
# IP95                      0.057258
# IVAR                      0.040663
# I55TH                     0.031433
# ...                            ...
# Return.5.count.2          0.002359
# H75TH                     0.001733
# Return.6.count.2          0.001450
# H80TH                     0.000513
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 32:
#                         importance
# ISD                       0.106707
# IP95                      0.068341
# IVAR                      0.053411
# ISKE                      0.046749
# I55TH                     0.025673
# ...                            ...
# I20TH                     0.001468
# Return.5.count.2          0.000826
# H55TH                     0.000071
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 33:
#                         importance
# ISD                       0.103771
# IP95                      0.053821
# IVAR                      0.049299
# ISKE                      0.047875
# I45TH                     0.033541
# ...                            ...
# HMODE                     0.001462
# HMEADIAN                  0.000826
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
# Return.5.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 34:
#                         importance
# ISD                       0.091707
# IP95                      0.058624
# IVAR                      0.052105
# ISKE                      0.042699
# I45TH                     0.031377
# ...                            ...
# Return.5.count.2          0.001474
# All.returns.above.mode    0.001372
# Return.6.count.2          0.001228
# IMAX                      0.001193
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 35:
#                         importance
# ISD                       0.104735
# IP95                      0.066954
# IVAR                      0.053027
# ISKE                      0.045504
# I45TH                     0.034244
# ...                            ...
# H25TH                     0.001143
# H90TH                     0.000974
# Return.6.count.2          0.000967
# Return.4.count.2          0.000692
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 36:
#                           importance
# ISD                         0.090347
# IVAR                        0.084895
# ISKE                        0.057305
# IP95                        0.050291
# I55TH                       0.022553
# ...                              ...
# First.returns.above.mode    0.002229
# Return.4.count.2            0.002043
# Return.5.count.2            0.001235
# Return.6.count.2            0.000000
# Return.7.count.above.2      0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 37:
#                         importance
# ISD                       0.097743
# IP95                      0.059363
# ISKE                      0.052572
# IVAR                      0.039718
# I55TH                     0.034916
# ...                            ...
# H05TH                     0.001850
# H55TH                     0.001097
# I40TH                     0.000623
# Return.6.count.2          0.000578
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 38:
#                         importance
# ISD                       0.097624
# ISKE                      0.062109
# IVAR                      0.058975
# IP95                      0.045954
# I55TH                     0.030860
# ...                            ...
# Return.6.count.2          0.001153
# b_median                  0.001115
# HMEADIAN                  0.000838
# Return.7.count.above.2    0.000281
# Return.5.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 39:
#                                 importance
# ISD                               0.097992
# IVAR                              0.067585
# ISKE                              0.064330
# IP95                              0.040556
# I55TH                             0.022461
# ...                                    ...
# Total.all.return.count.above.2    0.002078
# H01TH                             0.001055
# Return.2.count.above.2            0.001021
# Return.6.count.2                  0.000972
# Return.7.count.above.2            0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 40:
#                         importance
# ISD                       0.093202
# ISKE                      0.047800
# IP95                      0.046825
# IVAR                      0.041736
# I55TH                     0.032665
# ...                            ...
# HMEADIAN                  0.001689
# H30TH                     0.001468
# Return.6.count.2          0.000842
# Return.5.count.2          0.000767
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 41:
#                           importance
# ISD                         0.101847
# IP95                        0.061672
# ISKE                        0.052802
# IVAR                        0.051566
# IP80                        0.025352
# ...                              ...
# Total.first.return.count    0.002376
# IP65                        0.002076
# H01TH                       0.001603
# Return.6.count.2            0.001195
# Return.7.count.above.2      0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 42:
#                         importance
# ISD                       0.087732
# IVAR                      0.060007
# IP95                      0.055751
# ISKE                      0.052537
# I60TH                     0.025168
# ...                            ...
# HMEAN                     0.001667
# Return.6.count.2          0.001262
# HMEADIAN                  0.000926
# Return.7.count.above.2    0.000000
# Return.5.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 43:
#                         importance
# ISD                       0.082972
# IP95                      0.060976
# ISKE                      0.048401
# IVAR                      0.037229
# b_mean                    0.031089
# ...                            ...
# All.returns.above.mode    0.001275
# HMEADIAN                  0.000895
# All.returns.above.2       0.000772
# I05TH                     0.000116
# Return.7.count.above.2    0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 44:
#                         importance
# ISD                       0.089964
# IP95                      0.055583
# IVAR                      0.054322
# ISKE                      0.039546
# I55TH                     0.033452
# ...                            ...
# H05TH                     0.001688
# Return.5.count.2          0.001068
# H20TH                     0.000272
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 45:
#                           importance
# ISD                         0.090044
# IP95                        0.055870
# ISKE                        0.037741
# IVAR                        0.031974
# I45TH                       0.030643
# ...                              ...
# H50TH                       0.001807
# First.returns.above.mean    0.001386
# Return.5.count.2            0.001303
# Return.6.count.2            0.000000
# Return.7.count.above.2      0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 46:
#                         importance
# ISD                       0.093985
# IP95                      0.058915
# ISKE                      0.045592
# IVAR                      0.043478
# IP65                      0.031195
# ...                            ...
# H20TH                     0.001493
# HCV                       0.000998
# Return.6.count.2          0.000770
# Return.7.count.above.2    0.000000
# Return.5.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 47:
#                         importance
# ISD                       0.111986
# ISKE                      0.062603
# IP95                      0.050916
# IVAR                      0.038366
# I55TH                     0.029402
# ...                            ...
# I01TH                     0.001377
# Return.4.count.2          0.000982
# Return.6.count.2          0.000385
# Return.7.count.above.2    0.000000
# Return.5.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 48:
#                         importance
# ISD                       0.111196
# IVAR                      0.062674
# ISKE                      0.058527
# IP95                      0.048832
# I55TH                     0.038320
# ...                            ...
# I15TH                     0.001537
# H40TH                     0.001313
# Return.5.count.2          0.001205
# Return.7.count.above.2    0.000000
# Return.6.count.2          0.000000
#
# [92 rows x 1 columns]
# Features sorted by their score for estimator 49:
#                           importance
# ISD                         0.081727
# IP95                        0.059255
# ISKE                        0.047129
# IVAR                        0.044857
# I45TH                       0.029919
# ...                              ...
# IMEAN                       0.002202
# Total.first.return.count    0.001915
# H65TH                       0.001851
# Return.6.count.2            0.000000
# Return.7.count.above.2      0.000000
#
# [92 rows x 1 columns]

# %%
feature_names = X.columns.values.tolist()
importances = pd.Series(clf.feature_importances_,index=feature_names).sort_values(ascending=False)
importances - importances.tolist()
print(importances)
